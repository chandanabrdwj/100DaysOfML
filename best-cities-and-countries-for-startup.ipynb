# %% [markdown]
# <a href="https://www.kaggle.com/chandanarprasad/best-cities-and-countries-for-startup?scriptVersionId=84586793" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/best-cities-and-countries-for-startups-in-2021/Best Countries for Startups.csv
# /kaggle/input/best-cities-and-countries-for-startups-in-2021/Best Cities for Startups.csv

# %%
import pandas as pd

# %%
df_country = pd.read_csv('../input/best-cities-and-countries-for-startups-in-2021/Best Countries for Startups.csv')
df_city = pd.read_csv('../input/best-cities-and-countries-for-startups-in-2021/Best Cities for Startups.csv')

# %%
#Strip trailing whitespaces and replace space with underscore

df_country.columns = df_country.columns.str.strip()
df_country.columns = df_country.columns.str.replace(' ','_')

df_city.columns = df_city.columns.str.strip()
df_city.columns = df_city.columns.str.replace(' ','_')

# %%
df_country.head()
# Out:
#    ranking change_in_position_from_2020         country  total_score  \
# 0      1.0                            0   United States      124.420
# 1      2.0                            0  United Kingdom       28.719
# 2      3.0                            0          Israel       27.741
# 3      4.0                            0          Canada       19.876
# 4      5.0                            0         Germany       17.053
#
#    quantity_score  quality_score  business_score change_in_position_sign
# 0           19.45         101.17            3.80                     NaN
# 1            8.16          16.86            3.70                     NaN
# 2            5.48          19.14            3.13                     NaN
# 3            6.58           9.75            3.55                     NaN
# 4            3.64           9.93            3.49                     NaN

# %%
df_city.head(20)
# Out:
#     position change_in_position_from_2020                city  \
# 0          1                            0   San Francisco Bay
# 1          2                            0            New York
# 2          3                            3             Beijing
# 3          4                            1    Los Angeles Area
# 4          5                            2              London
# 5          6                            2         Boston Area
# 6          7                            3            Shanghai
# 7          8                            1       Tel Aviv Area
# 8          9                            0              Moscow
# 9         10                            4           Bangalore
# 10        11                            1               Paris
# 11        12                            1             Seattle
# 12        13                            5              Berlin
# 13        14                            1           New Delhi
# 14        15                            1               Tokyo
# 15        16                            6              Mumbai
# 16        17                            4             Chicago
# 17        18                            1              Austin
# 18        19                           11  Washington DC Area
# 19        20                            2           Sao Paulo
#
#             country  total_score  quatity_score  quality_score  \
# 0     United States      328.966          29.14         296.02
# 1     United States      110.777          11.43          95.55
# 2             China       66.049           5.01          58.61
# 3     United States       58.441          11.23          43.41
# 4    United Kingdom       56.913          15.77          37.44
# 5     United States       49.835           5.50          40.53
# 6             China       42.162           3.57          36.17
# 7            Israel       27.084           4.04          19.92
# 8            Russia       25.401           7.37          15.64
# 9             India       25.367           5.04          17.95
# 10           France       25.297           5.27          16.62
# 11    United States       24.329           3.49          17.04
# 12          Germany       23.872           4.03          16.35
# 13            India       22.379           5.88          13.90
# 14            Japan       21.792           2.50          16.00
# 15            India       19.414           3.27          13.54
# 16    United States       19.121           4.37          10.95
# 17    United States       18.598           3.20          11.60
# 18    United States       18.064           3.47          10.79
# 19           Brazil       17.642           2.63          12.72
#
#     business_score sign_of_change_in_position
# 0             3.80                        NaN
# 1             3.80                        NaN
# 2             2.43                          +
# 3             3.80                          +
# 4             3.70                          -
# 5             3.80                          -
# 6             2.43                          +
# 7             3.13                          -
# 8             2.39                        NaN
# 9             2.38                          +
# 10            3.41                          +
# 11            3.80                          -
# 12            3.49                          -
# 13            2.61                          +
# 14            3.30                          +
# 15            2.61                          +
# 16            3.80                          -
# 17            3.80                          -
# 18            3.80                          +
# 19            2.29                          -

# %%
print(df_country.isna().any().sum(),df_city.isna().any().sum())
# Out:
# 8 1

# %%
df_country[['country','ranking','total_score']].sort_values(by = 'total_score',ascending=False).head(10)
# Out:
#           country  ranking  total_score
# 0   United States      1.0      124.420
# 1  United Kingdom      2.0       28.719
# 2          Israel      3.0       27.741
# 3          Canada      4.0       19.876
# 4         Germany      5.0       17.053
# 5          Sweden      6.0       15.423
# 6           China      7.0       15.128
# 7     Switzerland      8.0       14.943
# 8       Australia      9.0       13.835
# 9       Singapore     10.0       13.745

# %%
df_country.tail(20)
# Out:
#      ranking change_in_position_from_2020                 country  \
# 81      82.0                            5                 Tunisia
# 82      83.0                            4                  Panama
# 83      84.0                            0                   Qatar
# 84      85.0                           12  Bosnia and Herzegovina
# 85      86.0                           15                 Ecuador
# 86      87.0                            4              Cape Verde
# 87      88.0                            5                Mongolia
# 88      89.0                           19              Azerbaijan
# 89      90.0                            2                  Kuwait
# 90      91.0                           11                Paraguay
# 91      92.0                            7               Sri Lanka
# 92      93.0                            5              Bangladesh
# 93      94.0                            1                 Somalia
# 94      95.0                           12                 Morocco
# 95      96.0                           18      Dominican Republic
# 96      97.0                            8                  Uganda
# 97      98.0                            2                   Nepal
# 98      99.0                   new  entry                 Namibia
# 99     100.0                   new  entry                Ethiopia
# 100      NaN                          NaN                     NaN
#
#      total_score  quantity_score  quality_score  business_score  \
# 81         0.395            0.14           0.07            0.19
# 82         0.355            0.09           0.08            0.19
# 83         0.352            0.10           0.09            0.17
# 84         0.351            0.10           0.08            0.17
# 85         0.330            0.12           0.06            0.15
# 86         0.319            0.15           0.05            0.11
# 87         0.314            0.10           0.05            0.16
# 88         0.309            0.09           0.05            0.17
# 89         0.259            0.04           0.09            0.12
# 90         0.253            0.07           0.06            0.12
# 91         0.245            0.09           0.04            0.12
# 92         0.241            0.08           0.08            0.09
# 93         0.224            0.14           0.05            0.04
# 94         0.220            0.06           0.05            0.12
# 95         0.197            0.06           0.04            0.09
# 96         0.180            0.07           0.04            0.07
# 97         0.172            0.06           0.04            0.08
# 98         0.165            0.04           0.05            0.07
# 99         0.162            0.07           0.06            0.03
# 100          NaN             NaN            NaN             NaN
#
#     change_in_position_sign
# 81                        -
# 82                        +
# 83                      NaN
# 84                        -
# 85                        -
# 86                        +
# 87                        +
# 88                        -
# 89                        +
# 90                        -
# 91                        +
# 92                        +
# 93                        +
# 94                        -
# 95                        -
# 96                        -
# 97                        +
# 98                      NaN
# 99                      NaN
# 100                     NaN

# %%
df_city.tail(20)
# Out:
#      position change_in_position_from_2020              city  \
# 980       981                           14              Kano
# 981       982                          new              Buea
# 982       983                           16            Maputo
# 983       984                           16           Algiers
# 984       985                            7             Kabul
# 985       986                          new           Yaounde
# 986       987                          new  Saint Peter Port
# 987       988                          new            Jhelum
# 988       989                          new    Port-au-Prince
# 989       990                          new            Multan
# 990       991                            8          Kinshasa
# 991       992                          new           Douglas
# 992       993                          new        Chattogram
# 993       994                            3        Bridgetown
# 994       995                          new           Cotonou
# 995       996                           26       Ouagadougou
# 996       997                          new           Baghdad
# 997       998                           13           Mbabane
# 998       999                          new           Conakry
# 999      1000                          new             Sanaa
#
#                                country  total_score  quatity_score  \
# 980                            Nigeria        0.076           0.01
# 981                           Cameroon        0.076           0.02
# 982                         Mozambique        0.074           0.02
# 983                            Algeria        0.071           0.01
# 984                        Afghanistan        0.070           0.02
# 985                           Cameroon        0.069           0.01
# 986                           Guernsey        0.069           0.05
# 987                           Pakistan        0.068           0.01
# 988                              Haiti        0.068           0.03
# 989                           Pakistan        0.067           0.01
# 990   Democratic Republic of the Congo        0.066           0.02
# 991                        Isle of Man        0.064           0.01
# 992                         Bangladesh        0.064           0.01
# 993                           Barbados        0.062           0.01
# 994                              Benin        0.061           0.01
# 995                       Burkina Faso        0.060           0.02
# 996                               Iraq        0.058           0.01
# 997                          Swaziland        0.057           0.01
# 998                             Guinea        0.047           0.01
# 999                              Yemen        0.037           0.01
#
#      quality_score  business_score sign_of_change_in_position
# 980           0.02            0.04                          +
# 981           0.02            0.04                        NaN
# 982           0.02            0.03                          -
# 983           0.03            0.03                          -
# 984           0.02            0.03                          +
# 985           0.02            0.03                        NaN
# 986           0.02            0.00                        NaN
# 987           0.02            0.04                        NaN
# 988           0.02            0.03                        NaN
# 989           0.02            0.04                        NaN
# 990           0.03            0.02                          +
# 991           0.05            0.00                        NaN
# 992           0.02            0.03                        NaN
# 993           0.02            0.03                          +
# 994           0.02            0.03                        NaN
# 995           0.02            0.02                          -
# 996           0.02            0.03                        NaN
# 997           0.02            0.03                          -
# 998           0.02            0.02                        NaN
# 999           0.02            0.01                        NaN
