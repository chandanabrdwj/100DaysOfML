# %% [markdown]
# <a href="https://www.kaggle.com/chandanarprasad/10-years-of-top-50-bestselling-books-on-amazon?scriptVersionId=82506950" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# Import required libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Read data
df = pd.read_csv('../input/amazon-top-50-bestselling-books-2009-2019/bestsellers with categories.csv')

# %%
df.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
df.shape
# Out:
# (550, 7)

# %%
df.describe().T
# Out:
#              count          mean           std     min     25%     50%  \
# User Rating  550.0      4.618364      0.226980     3.3     4.5     4.7
# Reviews      550.0  11953.281818  11731.132017    37.0  4058.0  8580.0
# Price        550.0     13.100000     10.842262     0.0     7.0    11.0
# Year         550.0   2014.000000      3.165156  2009.0  2011.0  2014.0
#
#                   75%      max
# User Rating      4.80      4.9
# Reviews      17253.25  87841.0
# Price           16.00    105.0
# Year          2017.00   2019.0

# %%
df.Year.value_counts().sort_index()
# Out:
# 2009    50
# 2010    50
# 2011    50
# 2012    50
# 2013    50
# 2014    50
# 2015    50
# 2016    50
# 2017    50
# 2018    50
# 2019    50
# Name: Year, dtype: int64

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

# %%
df.columns
# Out:
# Index(['Name', 'Author', 'User_Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
df.User_Rating.value_counts(normalize=True).sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
df.Author.value_counts().sort_index()
# Out:
# Abraham Verghese              2
# Adam Gasiewski                1
# Adam Mansbach                 1
# Adir Levy                     1
# Admiral William H. McRaven    1
#                              ..
# Walter Isaacson               3
# William Davis                 2
# William P. Young              2
# Wizards RPG Team              3
# Zhi Gang Sha                  2
# Name: Author, Length: 248, dtype: int64

# %%
df.Price.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
df.sort_values('Price', ascending=True)
# Out:
#                                                   Name  \
# 42          Cabin Fever (Diary of a Wimpy Kid, Book 6)
# 71             Diary of a Wimpy Kid: Hard Luck, Book 8
# 381                                        The Getaway
# 116                        Frozen (Little Golden Book)
# 505                              To Kill a Mockingbird
# ..                                                 ...
# 346  The Book of Basketball: The NBA According to T...
# 151                           Hamilton: The Revolution
# 473                       The Twilight Saga Collection
# 69   Diagnostic and Statistical Manual of Mental Di...
# 70   Diagnostic and Statistical Manual of Mental Di...
#
#                                Author  User_Rating  Reviews  Price  Year  \
# 42                        Jeff Kinney          4.8     4505      0  2011
# 71                        Jeff Kinney          4.8     6812      0  2013
# 381                       Jeff Kinney          4.8     5836      0  2017
# ...

# %%
df[df['Price'] == 0]
# Out:
#                                                   Name  \
# 42          Cabin Fever (Diary of a Wimpy Kid, Book 6)
# 71             Diary of a Wimpy Kid: Hard Luck, Book 8
# 116                        Frozen (Little Golden Book)
# 193                               JOURNEY TO THE ICE P
# 219                                  Little Blue Truck
# 358              The Constitution of the United States
# 381                                        The Getaway
# 461  The Short Second Life of Bree Tanner: An Eclip...
# 505                              To Kill a Mockingbird
# 506                              To Kill a Mockingbird
# 507                              To Kill a Mockingbird
# 508                              To Kill a Mockingbird
#
#                                Author  User_Rating  Reviews  Price  Year  \
# 42                        Jeff Kinney          4.8     4505      0  2011
# 71                        Jeff Kinney          4.8     6812      0  2013
# ...

# %%
df.Genre.value_counts()
# Out:
# Non Fiction    310
# Fiction        240
# Name: Genre, dtype: int64

# %%
df.Year.value_counts().sort_values()
# Out:
# 2016    50
# 2011    50
# 2018    50
# 2017    50
# 2019    50
# 2014    50
# 2010    50
# 2009    50
# 2015    50
# 2013    50
# 2012    50
# Name: Year, dtype: int64

# %%
df.sort_values(['Author','Price'],ascending=[True,False])
# Out:
#                                                   Name            Author  \
# 56                                   Cutting for Stone  Abraham Verghese
# 57                                   Cutting for Stone  Abraham Verghese
# 232  Milk and Vine: Inspirational Quotes From Class...    Adam Gasiewski
# 133                               Go the F**k to Sleep     Adam Mansbach
# 529  What Should Danny Do? (The Power to Choose Ser...         Adir Levy
# ..                                                 ...               ...
# 265             Player's Handbook (Dungeons & Dragons)  Wizards RPG Team
# 266             Player's Handbook (Dungeons & Dragons)  Wizards RPG Team
# 267             Player's Handbook (Dungeons & Dragons)  Wizards RPG Team
# 300  Soul Healing Miracles: Ancient and New Sacred ...      Zhi Gang Sha
# 78   Divine Soul Mind Body Healing and Transmission...      Zhi Gang Sha
#
#      User_Rating  Reviews  Price  Year        Genre
# ...

# %%
df.boxplot(column=['User_Rating'], return_type='axes');

# %%
sns.countplot(x = df['User_Rating'])
# Out:
# <AxesSubplot:xlabel='User_Rating', ylabel='count'>

# %%
ax = sns.boxplot(x="User_Rating", y="Year",orient="h",data=df)

# %%
df.corr()
# Out:
#              User_Rating   Reviews     Price      Year
# User_Rating     1.000000 -0.001729 -0.133086  0.242383
# Reviews        -0.001729  1.000000 -0.109182  0.263560
# Price          -0.133086 -0.109182  1.000000 -0.153979
# Year            0.242383  0.263560 -0.153979  1.000000

# %%
sns.pairplot(df,diag_kind="hist", height=4,hue ='Year',palette="vlag")

# %%
top_books_ten_years = df[df['User_Rating'] > 4.5]
top_books_ten_years = top_books_ten_years.groupby('Author')['User_Rating'].mean()
top_books_ten_years[:50]
# Out:
# Author
# Abraham Verghese              4.600000
# Adam Mansbach                 4.800000
# Adir Levy                     4.800000
# Admiral William H. McRaven    4.700000
# Alan Moore                    4.800000
# Alice Schertle                4.900000
# Allie Brosh                   4.700000
# Amor Towles                   4.700000
# Amy Shields                   4.800000
# Andy Weir                     4.700000
# Angie Grace                   4.600000
# Angie Thomas                  4.800000
# Ann Voskamp                   4.600000
# Ann Whitford Paul             4.800000
# Anthony Bourdain              4.800000
# Anthony Doerr                 4.600000
# Atul Gawande                  4.800000
# B. J. Novak                   4.800000
# Bessel van der Kolk M.D.      4.800000
# Bill Martin Jr.               4.900000
# Bill O'Reilly                 4.666667
# Bill Simmons                  4.700000
# Blue Star Coloring            4.600000
# Brandon Stanton               4.833333
# ...
