# %% [markdown]
# <a href="https://www.kaggle.com/chandanarprasad/apple-product-and-price-data?scriptVersionId=84308635" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/apple-product-price-list-from-26-countries-2022/apple product price list from 26 countries.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('../input/apple-product-price-list-from-26-countries-2022/apple product price list from 26 countries.csv')
df = df.drop(['pid','scraped_date'], axis=1)
df.head()
# Out:
#                      model         price country_code    country  \
# 0                iPhone 13  From A$1,199           au  Australia
# 1                iPhone SE    From A$679           au  Australia
# 2                iPhone 12    From A$999           au  Australia
# 3  AirPods(3rd generation)         A$279           au  Australia
# 4              AirPods Pro         A$399           au  Australia
#
#                 region income group
# 0  East Asia & Pacific  High income
# 1  East Asia & Pacific  High income
# 2  East Asia & Pacific  High income
# 3  East Asia & Pacific  High income
# 4  East Asia & Pacific  High income

# %%
df.model.value_counts().head(10)
# Out:
# MacBook Air             26
# iPhone 12               26
# iPhone SE               26
# AirPods Pro             26
# Apple TV 4K             26
# Apple Watch SE          26
# Apple Watch Series 3    26
# iPad                    26
# iPad Pro                26
# Magic Mouse             25
# Name: model, dtype: int64

# %%
df.country.value_counts().head(10)
# Out:
# Italy       18
# Mexico      18
# Turkey      18
# Russia      18
# Spain       18
# India       18
# Austria     18
# Thailand    17
# Sweden      17
# Portugal    17
# Name: country, dtype: int64

# %%
df.region.value_counts().head(10)
# Out:
# Europe & Central Asia        311
# East Asia & Pacific           51
# Latin America & Caribbean     34
# North America                 34
# South Asia                    18
# Name: region, dtype: int64

# %%
df['income group'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.model.value_counts().head(20)
# Out:
# MacBook Air                      26
# iPhone 12                        26
# iPhone SE                        26
# AirPods Pro                      26
# Apple TV 4K                      26
# Apple Watch SE                   26
# Apple Watch Series 3             26
# iPad                             26
# iPad Pro                         26
# Magic Mouse                      25
# iPhone 13                        21
# Apple TV HD                      17
# AirPods Max                      11
# Sport Band                        7
# 24-inch iMac²                     7
# Apple Pencil (2nd generation)     6
# AirPods(2nd generation)           6
# AirPods(3rd generation)           6
# iPhone 13 Pro                     5
# 24" iMac²                         3
# Name: model, dtype: int64
