# %% [markdown]
# <a href="https://www.kaggle.com/code/chandanarprasad/spending-habits-analysis?scriptVersionId=115563111" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/kaggle/input/analyzing-customer-spending-habits-to-improve-sa/SalesForCourse_quizz_table.csv')

# %%
df.shape
# Out:
# (34867, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34867 entries, 0 to 34866
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             34867 non-null  int64
#  1   Date              34866 non-null  object
#  2   Year              34866 non-null  float64
#  3   Month             34866 non-null  object
#  4   Customer Age      34866 non-null  float64
#  5   Customer Gender   34866 non-null  object
#  6   Country           34866 non-null  object
#  7   State             34866 non-null  object
#  8   Product Category  34866 non-null  object
#  9   Sub Category      34866 non-null  object
#  10  Quantity          34866 non-null  float64
#  11  Unit Cost         34866 non-null  float64
#  12  Unit Price        34866 non-null  float64
#  13  Cost              34866 non-null  float64
#  14  Revenue           34867 non-null  float64
#  15  Column1           2574 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['index', 'Date', 'Year', 'Month', 'Customer Age', 'Customer Gender',
#        'Country', 'State', 'Product Category', 'Sub Category', 'Quantity',
#        'Unit Cost', 'Unit Price', 'Cost', 'Revenue', 'Column1'],
#       dtype='object')

# %%
df.head()
# Out:
#    index      Date    Year     Month  Customer Age Customer Gender  \
# 0      0  02/19/16  2016.0  February          29.0               F
# 1      1  02/20/16  2016.0  February          29.0               F
# 2      2  02/27/16  2016.0  February          29.0               F
# 3      3  03/12/16  2016.0     March          29.0               F
# 4      4  03/12/16  2016.0     March          29.0               F
#
#          Country       State Product Category     Sub Category  Quantity  \
# 0  United States  Washington      Accessories  Tires and Tubes       1.0
# 1  United States  Washington         Clothing           Gloves       2.0
# 2  United States  Washington      Accessories  Tires and Tubes       3.0
# 3  United States  Washington      Accessories  Tires and Tubes       2.0
# 4  United States  Washington      Accessories  Tires and Tubes       3.0
#
#    Unit Cost  Unit Price   Cost  Revenue  Column1
# 0      80.00  109.000000   80.0    109.0      NaN
# ...

# %%
df.isna().all().sum()
# Out:
# 0

# %%
df.describe().T.round(2)
# Out:
#                 count      mean       std      min      25%      50%  \
# index         34867.0  17433.00  10065.38     0.00  8716.50  17433.0
# Year          34866.0   2015.57      0.50  2015.00  2015.00   2016.0
# Customer Age  34866.0     36.38     11.11    17.00    28.00     35.0
# Quantity      34866.0      2.00      0.81     1.00     1.00      2.0
# Unit Cost     34866.0    349.88    490.02     0.67    45.00    150.0
# Unit Price    34866.0    389.23    525.32     0.67    53.67    179.0
# Cost          34866.0    576.00    690.50     2.00    85.00    261.0
# Revenue       34867.0    640.87    736.64     2.00   102.00    319.0
# Column1        2574.0    688.05    774.20     2.00   104.25    390.5
#
#                    75%      max
# index         26149.50  34866.0
# Year           2016.00   2016.0
# Customer Age     44.00     87.0
# Quantity          3.00      3.0
# Unit Cost       455.00   3240.0
# Unit Price      521.00   5082.0
# Cost            769.00   3600.0
# ...

# %%
df.Country.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
df.Year.value_counts()
# Out:
# 2016.0    19847
# 2015.0    15019
# Name: Year, dtype: int64

# %%
df['Customer Age'].value_counts(bins=10)
# Out:
# (24.0, 31.0]      7991
# (31.0, 38.0]      7832
# (38.0, 45.0]      6610
# (16.929, 24.0]    5157
# (45.0, 52.0]      4098
# (52.0, 59.0]      2195
# (59.0, 66.0]       788
# (66.0, 73.0]       122
# (73.0, 80.0]        41
# (80.0, 87.0]        32
# Name: Customer Age, dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'Date', 'Year', 'Month', 'Customer Age', 'Customer Gender',
#        'Country', 'State', 'Product Category', 'Sub Category', 'Quantity',
#        'Unit Cost', 'Unit Price', 'Cost', 'Revenue', 'Column1'],
#       dtype='object')

# %%
df['Product Category'].value_counts()
# Out:
# Accessories    22534
# Bikes           7093
# Clothing        5239
# Name: Product Category, dtype: int64

# %%
df['Sub Category'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[df['Sub Category'] == 'Shorts']['Country'].value_counts()
# Out:
# United States     455
# France             53
# United Kingdom     49
# Germany             9
# Name: Country, dtype: int64

# %%
df[df['Sub Category'] == 'Shorts']['State'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[df['Sub Category'] == 'Gloves']['Country'].value_counts()
# Out:
# United States     296
# United Kingdom     77
# France             54
# Germany            53
# Name: Country, dtype: int64

# %%
df[df['Sub Category'] == 'Gloves']['State'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[df['Sub Category'] == 'Socks']['Country'].value_counts()
# Out:
# United States     234
# United Kingdom     63
# Germany            35
# France             32
# Name: Country, dtype: int64

# %%
df[df['Sub Category'] == 'Socks']['State'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[df['Country'] == 'United States']['Product Category'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Product Category'>

# %%
df[df['State'] == 'Washington']['Product Category'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Product Category'>

# %%
df[df['Country'] == 'United Kingdom']['Product Category'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Product Category'>

# %%
df[df['State'] == 'England']['Product Category'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Product Category'>

# %%
df[df['Country'] == 'Germany']['Product Category'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Product Category'>

# %%
df[df['State'] == 'Hamburg']['Product Category'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Product Category'>
