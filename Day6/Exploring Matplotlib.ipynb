# %% [markdown]
# ## Matplotlib Library

# %% [markdown]
# ### [Reference] Youtube Tutorial - Keith Galli

# %% [markdown]
# #### Load Necessary Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #### Basic graph

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# resize the graph

plt.figure(figsize=(3,2), dpi=150)



#plt.plot(x,y,label="2x",color='red',linewidth=2, marker='.',markersize=10)

#short hand notation for plotting quickly: '[color][marker][line]'

plt.plot(x,y, 'b.--', label='2x')

# line 2
x2 = np.arange(0,4.5,0.5)
plt.plot(x2[:6], x2[:6]**2, 'r',label='x**2')
plt.plot(x2[5:],x2[5:]**2, 'r--')



plt.title("our first graph")
plt.xlabel('xlable')
plt.ylabel('ylable')

plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])

plt.legend()

plt.savefig('mygraph.png',dpi=300)

plt.show()

# %% [markdown]
# ### Additional resources  - Bokeh
# https://www.geeksforgeeks.org/python-data-visualization-using-bokeh/

# %%
labels = ['A','B','C','D','E']
values = [8,4,5,7,6]

bars = plt.bar(labels,values)
#bars[0].set_hatch('/')
#bars[1].set_hatch('o')
#bars[2].set_hatch('*')
#bars[3].set_hatch('-')
#bars[4].set_hatch('+')

patterns = ['/','o','*','-','+']
for bar in bars:
    bar.set_hatch(patterns.pop(0))



plt.figure(figsize=(6,4))

plt.show()
