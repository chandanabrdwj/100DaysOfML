# %% [markdown]
# <a href="https://www.kaggle.com/chandanarprasad/kaggle-metadata-analysis?scriptVersionId=85377134" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

# %%
kernel_lang = pd.read_csv('../input/meta-kaggle/KernelLanguages.csv')
kernel_lang
# Out:
#    Id                         Name DisplayName  IsNotebook
# 0   1                            R           R       False
# 1   2                       Python      Python       False
# 2   5                    RMarkdown           R       False
# 3   8             IPython Notebook      Python        True
# 4   9        IPython Notebook HTML      Python       False
# 5  12              R Notebook HTML           R       False
# 6  13                   R Notebook           R        True
# 7  14  Python Script - Interactive      Python        True
# 8  15       R Script - Interactive           R        True
# 9  16      RMarkdown - Interactive           R        True

# %%
comp = pd.read_csv('../input/meta-kaggle/Competitions.csv')
comp.head()
# Out:
#      Id            Slug                                  Title  \
# 0  2408  Eurovision2010             Forecast Eurovision Voting
# 1  2435  hivprogression                Predict HIV Progression
# 2  2438    worldcup2010    World Cup 2010 - Take on the Quants
# 3  2439     informs2010       INFORMS Data Mining Contest 2010
# 4  2442    worldcupconf  World Cup 2010 - Confidence Challenge
#
#                                             Subtitle HostSegmentTitle  \
# 0  This competition requires contestants to forec...         Featured
# 1  This contest requires competitors to predict t...         Featured
# 2  Quants at Goldman Sachs and JP Morgan have mod...         Featured
# 3  The goal of this contest is to predict short t...         Featured
# 4  The Confidence Challenge requires competitors ...         Featured
#
#    ForumId  OrganizationId  CompetitionTypeId HostName          EnabledDate  \
# 0      2.0             NaN                  1      NaN  04/07/2010 07:57:43
# ...

# %%
# Competition submission numbers crossing 100,000
comp[comp.TotalSubmissions > 100000]['Title']
# Out:
# 854                      Home Credit Default Risk
# 1037    Santander Customer Transaction Prediction
# 1667                     IEEE-CIS Fraud Detection
# 2727            SIIM-ISIC Melanoma Classification
# Name: Title, dtype: object

# %%
# Competitions where reward quanitiy crosses 100,000
comp[comp.RewardQuantity > 100000]['Title']
# Out:
# 17                                  Heritage Health Prize
# 82                                        GE Flight Quest
# 128     Flight Quest 2: Flight Optimization, Milestone...
# 139       Flight Quest 2: Flight Optimization, Main Phase
# 156      Flight Quest 2: Flight Optimization, Final Phase
# 194                            National Data Science Bowl
# 284                       Second Annual Data Science Bowl
# 390           The Nature Conservancy Fisheries Monitoring
# 440                                Data Science Bowl 2017
# 506     Zillow Prize: Zillow’s Home Value Prediction (...
# 525               Passenger Screening Algorithm Challenge
# 1666                    Severstal: Steel Defect Detection
# 2002                               2019 Data Science Bowl
# 2077                         Deepfake Detection Challenge
# Name: Title, dtype: object

# %%
# Range of number of submission and its distribution 
comp.TotalSubmissions.value_counts(bins=10)
# Out:
# (-131.889, 13188.8]     4820
# (13188.8, 26377.6]        70
# (26377.6, 39566.4]        34
# (39566.4, 52755.2]        17
# (65944.0, 79132.8]         8
# (52755.2, 65944.0]         7
# (79132.8, 92321.6]         6
# (92321.6, 105510.4]        4
# (118699.2, 131888.0]       2
# (105510.4, 118699.2]       0
# Name: TotalSubmissions, dtype: int64

# %%
users = pd.read_csv('../input/meta-kaggle/Users.csv')
users.head()
# Out:
#     Id      UserName        DisplayName RegisterDate  PerformanceTier
# 0    1    kaggleteam        Kaggle Team   03/24/2011                5
# 1  368  antgoldbloom  Anthony Goldbloom   01/20/2010                5
# 2  381        iguyon           Isabelle   01/29/2010                2
# 3  383  davidstephan      David Stephan   02/01/2010                0
# 4  384    gabewarren        Gabe Warren   02/02/2010                0

# %%
user_ach = pd.read_csv('../input/meta-kaggle/UserAchievements.csv')
user_ach.head()
# Out:
#         Id  UserId AchievementType  Tier TierAchievementDate  Points  \
# 0  3739822       1      Discussion     1          11/06/2019       0
# 1  3916402       1    Competitions     1          11/06/2019       0
# 2  3739823     368    Competitions     1          07/15/2016     318
# 3  3739824     368         Scripts     2          09/21/2016      47
# 4  3739825     368      Discussion     2          08/30/2016     103
#
#    CurrentRanking  HighestRanking  TotalGold  TotalSilver  TotalBronze
# 0             NaN             3.0          0            0           14
# 1             NaN             NaN          0            0            0
# 2             NaN            75.0          0            0            0
# 3             NaN             NaN          0            3           12
# 4             NaN             NaN         13           13          137
