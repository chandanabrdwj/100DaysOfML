# %% [markdown]
# <a href="https://www.kaggle.com/code/chandanarprasad/wallstreet-journal-company-ranking?scriptVersionId=111627933" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("../input/250-best-managed-companies-wsj-and-drucker-inst/wsj_250_best-managed_companies.csv",sep=",", encoding='cp1252')
df.head()
# Out:
#    sort_order  rank                                company  overall_score  \
# 0           1     1                        Microsoft Corp.          105.5
# 1           2     2                        Amazon.com Inc.           94.3
# 2           3     3                             Apple Inc.           91.6
# 3           4     4  International Business Machines Corp.           88.9
# 4           5     5                            Intel Corp.           82.9
#
#   change_from_2019  customer_satisfaction  \
# 0           up 2.5                      4
# 1           up 0.4                      3
# 2         down 4.4                      4
# 3         down 6.8                      5
# 4         down 1.6                      4
#
#    employee_engagement_and_development  innovation  social_responsibility  \
# 0                                    5           6                      5
# 1                                    3           6                      3
# ...

# %%
df.columns
# Out:
# Index(['sort_order', 'rank', 'company', 'overall_score', 'change_from_2019',
#        'customer_satisfaction', 'employee_engagement_and_development',
#        'innovation', 'social_responsibility', 'financial_strength', 'sector'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   sort_order                           252 non-null    int64
#  1   rank                                 252 non-null    int64
#  2   company                              252 non-null    object
#  3   overall_score                        252 non-null    float64
#  4   change_from_2019                     249 non-null    object
#  5   customer_satisfaction                252 non-null    int64
#  6   employee_engagement_and_development  252 non-null    int64
#  7   innovation                           252 non-null    int64
#  8   social_responsibility                252 non-null    int64
#  9   financial_strength                   252 non-null    int64
#  10  sector                               252 non-null    object
# ...

# %%
df.describe().T.round(2)
# Out:
#                                      count    mean    std   min    25%    50%  \
# sort_order                           252.0  126.50  72.89   1.0  63.75  126.5
# rank                                 252.0  125.77  72.54   1.0  63.00  123.0
# overall_score                        252.0   62.28   7.41  54.3  57.10   60.0
# customer_satisfaction                252.0    3.75   0.89   1.0   3.00    4.0
# employee_engagement_and_development  252.0    3.66   0.71   1.0   3.00    4.0
# innovation                           252.0    3.67   0.87   2.0   3.00    3.0
# social_responsibility                252.0    4.08   0.70   2.0   4.00    4.0
# financial_strength                   252.0    3.47   0.93   1.0   3.00    3.0
#
#                                         75%    max
# sort_order                           189.25  252.0
# rank                                 187.00  249.0
# overall_score                         66.00  105.5
# customer_satisfaction                  4.00    5.0
# ...

# %%
df.sector.value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.groupby('financial_strength').first()
# Out:
#                     sort_order  rank                                company  \
# financial_strength
# 1                          150   150                   Delta Air Lines Inc.
# 2                           56    55                           Raytheon Co.
# 3                            4     4  International Business Machines Corp.
# 4                            8     8                     Cisco Systems Inc.
# 5                            1     1                        Microsoft Corp.
#
#                     overall_score change_from_2019  customer_satisfaction  \
# financial_strength
# 1                            59.2           up 2.6                      4
# 2                            66.7         down 0.1                      4
# 3                            88.9         down 6.8                      5
# 4                            80.5         down 4.8                      5
# 5                           105.5           up 2.5                      4
#
# ...

# %%
df.groupby('customer_satisfaction').first()
# Out:
#                        sort_order  rank  \
# customer_satisfaction
# 1                              32    31
# 2                              51    51
# 3                               2     2
# 4                               1     1
# 5                               4     4
#
#                                                      company  overall_score  \
# customer_satisfaction
# 1                                       Meta Platforms Inc.*           69.4
# 2                                              Qualcomm Inc.           67.2
# 3                                            Amazon.com Inc.           94.3
# 4                                            Microsoft Corp.          105.5
# 5                      International Business Machines Corp.           88.9
#
#                       change_from_2019  employee_engagement_and_development  \
# customer_satisfaction
# 1                             down 7.8                                    5
# ...

# %%
df.groupby('innovation').first()
# Out:
#             sort_order  rank          company  overall_score change_from_2019  \
# innovation
# 2                  116   115    Prologis Inc.           60.6           up 2.9
# 3                   30    30  S&P Global Inc.           69.6         down 1.9
# 4                   10    10          HP Inc.           77.5         down 2.7
# 5                    5     5      Intel Corp.           82.9         down 1.6
# 6                    1     1  Microsoft Corp.          105.5           up 2.5
#
#             customer_satisfaction  employee_engagement_and_development  \
# innovation
# 2                               4                                    5
# 3                               5                                    4
# 4                               5                                    4
# 5                               4                                    4
# 6                               4                                    5
#
# ...

# %%
df.groupby('social_responsibility').first()
# Out:
#                        sort_order  rank                 company  \
# social_responsibility
# 2                             163   163  Uber Technologies Inc.
# 3                               2     2         Amazon.com Inc.
# 4                               9     9    Procter & Gamble Co.
# 5                               1     1         Microsoft Corp.
#
#                        overall_score change_from_2019  customer_satisfaction  \
# social_responsibility
# 2                               58.4           up 3.9                      3
# 3                               94.3           up 0.4                      3
# 4                               79.7         down 3.8                      5
# 5                              105.5           up 2.5                      4
#
#                        employee_engagement_and_development  innovation  \
# social_responsibility
# 2                                                        4           5
# ...

# %%
df_tech = df[df.sector == 'Technology']

# %%
df_tech.shape
# Out:
# (46, 11)

# %%
df_tech.company
# Out:
# 0                            Microsoft Corp.
# 1                            Amazon.com Inc.
# 2                                 Apple Inc.
# 3      International Business Machines Corp.
# 4                                Intel Corp.
# 5                               Nvidia Corp.
# 7                         Cisco Systems Inc.
# 9                                    HP Inc.
# 11                                Adobe Inc.
# 12                             Alphabet Inc.
# 21                       Salesforce.com Inc.
# 24               Advanced Micro Devices Inc.
# 31                      Meta Platforms Inc.*
# 39                                 eBay Inc.
# 40                              Oracle Corp.
# 44                        Lam Research Corp.
# 47                    Applied Materials Inc.
# 50                             Qualcomm Inc.
# 51                    Dell Technologies Inc.
# 54            Hewlett Packard Enterprise Co.
# 63                    Texas Instruments Inc.
# ...

# %%
df_tech.isna().sum().any()
# Out:
# False

# %%
df_tech.sort_values(by="employee_engagement_and_development",ascending=False).head(10)
# Out:
#     sort_order  rank                      company  overall_score  \
# 0            1     1              Microsoft Corp.          105.5
# 21          22    22          Salesforce.com Inc.           72.1
# 92          93    91                 Workday Inc.           62.3
# 80          81    79                  VMware Inc.           63.8
# 76          77    77                  Intuit Inc.           63.9
# 63          64    63       Texas Instruments Inc.           66.0
# 31          32    31         Meta Platforms Inc.*           69.4
# 24          25    25  Advanced Micro Devices Inc.           70.9
# 85          86    86                Autodesk Inc.           63.1
# 7            8     8           Cisco Systems Inc.           80.5
#
#    change_from_2019  customer_satisfaction  \
# 0            up 2.5                      4
# 21                0                      4
# 92         down 0.2                      5
# 80         down 4.7                      4
# ...

# %%
df_tech.sort_values(by="employee_engagement_and_development",ascending=True).head(10)
# Out:
#      sort_order  rank                                company  overall_score  \
# 51           52    52                 Dell Technologies Inc.           66.9
# 236         237   236                   Xerox Holdings Corp.           54.9
# 221         222   219                 Seagate Technology PLC           55.7
# 1             2     2                        Amazon.com Inc.           94.3
# 3             4     4  International Business Machines Corp.           88.9
# 201         202   201                  NXP Semiconductors NV           56.7
# 169         170   169                 ON Semiconductor Corp.           58.0
# 223         224   223                            Garmin Ltd.           55.6
# 40           41    40                           Oracle Corp.           68.7
# 243         244   244             L3Harris Technologies Inc.           54.6
#
#     change_from_2019  customer_satisfaction  \
# 51          down 2.0                      4
# ...

# %%
df_tech.sort_values(by="innovation",ascending=False).head(10)
# Out:
#     sort_order  rank                                company  overall_score  \
# 0            1     1                        Microsoft Corp.          105.5
# 2            3     3                             Apple Inc.           91.6
# 3            4     4  International Business Machines Corp.           88.9
# 1            2     2                        Amazon.com Inc.           94.3
# 31          32    31                   Meta Platforms Inc.*           69.4
# 51          52    52                 Dell Technologies Inc.           66.9
# 50          51    51                          Qualcomm Inc.           67.2
# 40          41    40                           Oracle Corp.           68.7
# 39          40    40                              eBay Inc.           68.7
# 21          22    22                    Salesforce.com Inc.           72.1
#
#    change_from_2019  customer_satisfaction  \
# 0            up 2.5                      4
# 2          down 4.4                      4
# ...

# %%
df_tech.sort_values(by="innovation",ascending=True).head(10)
# Out:
#      sort_order  rank                      company  overall_score  \
# 80           81    79                  VMware Inc.           63.8
# 92           93    91                 Workday Inc.           62.3
# 113         114   113  Cadence Design Systems Inc.           60.7
# 145         146   141                  Square Inc.           59.4
# 146         147   141                  Xilinx Inc.           59.4
# 151         152   150                Synopsys Inc.           59.2
# 165         166   166          Analog Devices Inc.           58.2
# 169         170   169       ON Semiconductor Corp.           58.0
# 189         190   187              ServiceNow Inc.           57.1
# 193         194   191                  NetApp Inc.           57.0
#
#     change_from_2019  customer_satisfaction  \
# 80          down 4.7                      4
# 92          down 0.2                      5
# 113         down 0.7                      4
# 145           up 3.5                      4
# ...

# %%
df_tech.sort_values(by="overall_score",ascending=False).head(10)
# Out:
#     sort_order  rank                                company  overall_score  \
# 0            1     1                        Microsoft Corp.          105.5
# 1            2     2                        Amazon.com Inc.           94.3
# 2            3     3                             Apple Inc.           91.6
# 3            4     4  International Business Machines Corp.           88.9
# 4            5     5                            Intel Corp.           82.9
# 5            6     6                           Nvidia Corp.           81.1
# 7            8     8                     Cisco Systems Inc.           80.5
# 9           10    10                                HP Inc.           77.5
# 11          12    12                             Adobe Inc.           76.3
# 12          13    13                          Alphabet Inc.           76.1
#
#    change_from_2019  customer_satisfaction  \
# 0            up 2.5                      4
# 1            up 0.4                      3
# ...

# %%
df_tech.sort_values(by="overall_score",ascending=True).head(10)
# Out:
#      sort_order  rank                     company  overall_score  \
# 248         249   249                  Ansys Inc.           54.3
# 243         244   244  L3Harris Technologies Inc.           54.6
# 235         236   236         Citrix Systems Inc.           54.9
# 236         237   236        Xerox Holdings Corp.           54.9
# 223         224   223                 Garmin Ltd.           55.6
# 221         222   219      Seagate Technology PLC           55.7
# 215         216   216                   KLA Corp.           56.0
# 214         215   212       Western Digital Corp.           56.1
# 212         213   212     Motorola Solutions Inc.           56.1
# 204         205   205       Juniper Networks Inc.           56.5
#
#     change_from_2019  customer_satisfaction  \
# 248         down 1.6                      4
# 243           up 4.6                      3
# 235         down 3.8                      3
# 236         down 2.6                      4
# ...

# %%
df_tech.sort_values(by="customer_satisfaction",ascending=False).head(10)
# Out:
#      sort_order  rank                                company  overall_score  \
# 92           93    91                           Workday Inc.           62.3
# 3             4     4  International Business Machines Corp.           88.9
# 5             6     6                           Nvidia Corp.           81.1
# 7             8     8                     Cisco Systems Inc.           80.5
# 9            10    10                                HP Inc.           77.5
# 204         205   205                  Juniper Networks Inc.           56.5
# 169         170   169                 ON Semiconductor Corp.           58.0
# 40           41    40                           Oracle Corp.           68.7
# 151         152   150                          Synopsys Inc.           59.2
# 113         114   113            Cadence Design Systems Inc.           60.7
#
#     change_from_2019  customer_satisfaction  \
# 92          down 0.2                      5
# ...

# %%
df_tech.sort_values(by="customer_satisfaction",ascending=True).head(10)
# Out:
#      sort_order  rank                     company  overall_score  \
# 31           32    31        Meta Platforms Inc.*           69.4
# 50           51    51               Qualcomm Inc.           67.2
# 85           86    86               Autodesk Inc.           63.1
# 235         236   236         Citrix Systems Inc.           54.9
# 223         224   223                 Garmin Ltd.           55.6
# 221         222   219      Seagate Technology PLC           55.7
# 215         216   216                   KLA Corp.           56.0
# 243         244   244  L3Harris Technologies Inc.           54.6
# 162         163   163      Uber Technologies Inc.           58.4
# 12           13    13               Alphabet Inc.           76.1
#
#     change_from_2019  customer_satisfaction  \
# 31          down 7.8                      1
# 50            up 0.7                      2
# 85          down 0.5                      3
# 235         down 3.8                      3
# ...

# %%
df_tech.sort_values(by="financial_strength",ascending=False).head(10)
# Out:
#      sort_order  rank                 company  overall_score change_from_2019  \
# 0             1     1         Microsoft Corp.          105.5           up 2.5
# 215         216   216               KLA Corp.           56.0         down 3.9
# 145         146   141             Square Inc.           59.4           up 3.5
# 63           64    63  Texas Instruments Inc.           66.0         down 1.4
# 50           51    51           Qualcomm Inc.           67.2           up 0.7
# 47           48    48  Applied Materials Inc.           67.5           up 3.1
# 44           45    45      Lam Research Corp.           68.1           up 4.5
# 40           41    40            Oracle Corp.           68.7         down 3.3
# 31           32    31    Meta Platforms Inc.*           69.4         down 7.8
# 1             2     2         Amazon.com Inc.           94.3           up 0.4
#
#      customer_satisfaction  employee_engagement_and_development  innovation  \
# ...

# %%
df_tech.sort_values(by="financial_strength",ascending=True).head(10)
# Out:
#      sort_order  rank                  company  overall_score  \
# 236         237   236     Xerox Holdings Corp.           54.9
# 214         215   212    Western Digital Corp.           56.1
# 204         205   205    Juniper Networks Inc.           56.5
# 162         163   163   Uber Technologies Inc.           58.4
# 92           93    91             Workday Inc.           62.3
# 80           81    79              VMware Inc.           63.8
# 235         236   236      Citrix Systems Inc.           54.9
# 212         213   212  Motorola Solutions Inc.           56.1
# 201         202   201    NXP Semiconductors NV           56.7
# 169         170   169   ON Semiconductor Corp.           58.0
#
#     change_from_2019  customer_satisfaction  \
# 236         down 2.6                      4
# 214         down 1.5                      4
# 204         down 2.5                      5
# 162           up 3.9                      3
# 92          down 0.2                      5
# ...

# %%
df[df.financial_strength == df.financial_strength.max()]
# Out:
#      sort_order  rank                            company  overall_score  \
# 0             1     1                    Microsoft Corp.          105.5
# 1             2     2                    Amazon.com Inc.           94.3
# 2             3     3                         Apple Inc.           91.6
# 4             5     5                        Intel Corp.           82.9
# 5             6     6                       Nvidia Corp.           81.1
# 6             7     7                  Johnson & Johnson           80.9
# 8             9     9               Procter & Gamble Co.           79.7
# 9            10    10                            HP Inc.           77.5
# 11           12    12                         Adobe Inc.           76.3
# 12           13    13                      Alphabet Inc.           76.1
# 13           14    14                      Accenture PLC           75.8
# 19           20    20                          Nike Inc.           72.9
# ...

# %%
df[df.social_responsibility == df.social_responsibility.max()]
# Out:
#      sort_order  rank                                company  overall_score  \
# 0             1     1                        Microsoft Corp.          105.5
# 2             3     3                             Apple Inc.           91.6
# 3             4     4  International Business Machines Corp.           88.9
# 4             5     5                            Intel Corp.           82.9
# 5             6     6                           Nvidia Corp.           81.1
# ..          ...   ...                                    ...            ...
# 172         173   173                Boston Scientific Corp.           57.8
# 192         193   191                             Hess Corp.           57.0
# 208         209   209                       Baker Hughes Co.           56.2
# 236         237   236                   Xerox Holdings Corp.           54.9
# 239         240   240                     ManpowerGroup Inc.           54.7
#
#     change_from_2019  customer_satisfaction  \
# ...

# %%
df[df.innovation == df.innovation.max()]
# Out:
#    sort_order  rank                                company  overall_score  \
# 0           1     1                        Microsoft Corp.          105.5
# 1           2     2                        Amazon.com Inc.           94.3
# 2           3     3                             Apple Inc.           91.6
# 3           4     4  International Business Machines Corp.           88.9
#
#   change_from_2019  customer_satisfaction  \
# 0           up 2.5                      4
# 1           up 0.4                      3
# 2         down 4.4                      4
# 3         down 6.8                      5
#
#    employee_engagement_and_development  innovation  social_responsibility  \
# 0                                    5           6                      5
# 1                                    3           6                      3
# 2                                    4           6                      5
# 3                                    3           6                      5
#
# ...

# %%
df[df.employee_engagement_and_development == df.employee_engagement_and_development.max()]
# Out:
#      sort_order  rank                      company  overall_score  \
# 0             1     1              Microsoft Corp.          105.5
# 5             6     6                 Nvidia Corp.           81.1
# 7             8     8           Cisco Systems Inc.           80.5
# 8             9     9         Procter & Gamble Co.           79.7
# 11           12    12                   Adobe Inc.           76.3
# 21           22    22          Salesforce.com Inc.           72.1
# 24           25    25  Advanced Micro Devices Inc.           70.9
# 27           28    28                    Etsy Inc.           70.1
# 31           32    31         Meta Platforms Inc.*           69.4
# 37           38    38        Colgate-Palmolive Co.           68.9
# 61           62    61              Mastercard Inc.           66.2
# 63           64    63       Texas Instruments Inc.           66.0
# 76           77    77                  Intuit Inc.           63.9
# ...

# %%
df[df.customer_satisfaction == df.customer_satisfaction.max()]
# Out:
#      sort_order  rank                                  company  overall_score  \
# 3             4     4    International Business Machines Corp.           88.9
# 5             6     6                             Nvidia Corp.           81.1
# 7             8     8                       Cisco Systems Inc.           80.5
# 8             9     9                     Procter & Gamble Co.           79.7
# 9            10    10                                  HP Inc.           77.5
# 10           11    11                             PepsiCo Inc.           77.4
# 13           14    14                            Accenture PLC           75.8
# 15           16    16                       General Motors Co.           75.1
# 19           20    20                                Nike Inc.           72.9
# 20           21    21                                Visa Inc.           72.8
# 23           24    24               Edwards Lifesciences Corp.           71.6
# ...

# %%
df[df.overall_score == df.overall_score.max()]
# Out:
#    sort_order  rank          company  overall_score change_from_2019  \
# 0           1     1  Microsoft Corp.          105.5           up 2.5
#
#    customer_satisfaction  employee_engagement_and_development  innovation  \
# 0                      4                                    5           6
#
#    social_responsibility  financial_strength      sector
# 0                      5                   5  Technology
